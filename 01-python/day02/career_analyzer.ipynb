# %%
print("=========================")
print(" Career Analyzer")
print("=========================")
# Out:
# ...
#  Career Analyzer
# ...

# %%
employee_name = "Anand Kelkar"
employee_experience = 20
current_skills = [
    "BizTalk",
    "MuleSoft",
    "IBM MQ",
    "SQL",
    "REST APIs"
]
target_role = "Enterprise GenAI Architect"

# %%
print(f"Employee Name       : {employee_name}")
print(f"Employee Experience : {employee_experience}")
print("Current Skills:")

for skill in current_skills:
    print(f" - {skill}")
print(f"Target Role         : {target_role}")
# Out:
# Employee Name       : Anand Kelkar
# Employee Experience : 20
# Current Skills:
#  - BizTalk
#  - MuleSoft
#  - IBM MQ
#  - SQL
#  - REST APIs
# Target Role         : Enterprise GenAI Architect

# %%
TOTAL_BOOTCAMP_DAYS = 200
COMPLETED_DAYS = 2
remaining_days = TOTAL_BOOTCAMP_DAYS - COMPLETED_DAYS
print(f"Remainig days : {remaining_days}")
# Out:
# Remainig days : 198

# %%
total_progress = (COMPLETED_DAYS * 100 )/TOTAL_BOOTCAMP_DAYS
print(f"Total Progress : {int(total_progress)}%")
# Out:
# Total Progress : 1%
