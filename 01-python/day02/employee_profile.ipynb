# %%
name = "Anand Kelkar"
experience = 20
target_role = "Enterprise GenAI Architect"
salary_goal = 6000000

# %%
print(f"Name        : {name}")
print(f"Experience  : {experience}")
print(f"Target Role : {target_role}")
print(f"Salary Goal : {salary_goal}")
# Out:
# Name        : Anand Kelkar
# Experience  : 20
# Target Role : Enterprise GenAI Architect
# Salary Goal : 6000000

# %%
skills = [
    "BizTalk",
    "MuleSoft",
    "IBM MQ",
    "SQL",
    "REST APIs"
]

for index, skill in enumerate(skills):
    print(f"Skill {index+1} : {skill}")
# Out:
# Skill 1 : BizTalk
# Skill 2 : MuleSoft
# Skill 3 : IBM MQ
# Skill 4 : SQL
# Skill 5 : REST APIs

# %%
career = {
    "Current Role": "Enterprise integration Architect",
    "Experience": 20,
    "Target": "GenAI Enterprise Architect",
    "Country": "India"
}

for key, value in career.items():
    print(f"{key} : {value}")
# Out:
# Current Role : Enterprise integration Architect
# Experience : 20
# Target : GenAI Enterprise Architect
# Country : India

# %%
technologies = {
    "Python",
    "MuleSoft",
    "Python",
    "Git",
    "Git"
}

# %% [markdown]
# ##### sets does not allow duplicate values , Hence output will ne unique values

# %%
technologies
# Out:
# {'Git', 'MuleSoft', 'Python'}

# %%
coordinates = (17.3850, 78.4867)
print(f"Latitude : {coordinates[0]}")
print(f"Longitude : {coordinates[1]}")
# Out:
# Latitude : 17.385
# Longitude : 78.4867
