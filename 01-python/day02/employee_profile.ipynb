# %%
name = "Anand Kelkar"
experience = 20
target_role = "Enterprise GenAI Architect"
salary_goal = 6000000

# %%
print(name)
print(experience)
print(target_role)
print(salary_goal)
# Out:
# Anand Kelkar
# 20
# Enterprise GenAI Architect
# 6000000

# %%
skills = [
    "BizTalk",
    "MuleSoft",
    "IBM MQ",
    "SQL",
    "REST APIs"
]

for skill in ski
